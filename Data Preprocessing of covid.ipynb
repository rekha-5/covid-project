# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing Dataset

# %%
data_set =pd.read_csv("country_wise_latest.csv")
x=data_set.iloc[:,:-1].values
Y=data_set.iloc[:,-1].values

# %%
print(x)
# Out:
# [['Afghanistan' 36263 1269 ... 35526 737 2.07]
#  ['Albania' 4880 144 ... 4171 709 17.0]
#  ['Algeria' 27973 1163 ... 23691 4282 18.07]
#  ...
#  ['Yemen' 1691 483 ... 1619 72 4.45]
#  ['Zambia' 4552 140 ... 3326 1226 36.86]
#  ['Zimbabwe' 2704 36 ... 1713 991 57.85]]

# %%
print(Y)
# Out:
# ['Eastern Mediterranean' 'Europe' 'Africa' 'Europe' 'Africa' 'Americas'
#  'Americas' 'Europe' 'Western Pacific' 'Europe' 'Europe' 'Americas'
#  'Eastern Mediterranean' 'South-East Asia' 'Americas' 'Europe' 'Europe'
#  'Americas' 'Africa' 'South-East Asia' 'Americas' 'Europe' 'Africa'
#  'Americas' 'Western Pacific' 'Europe' 'Africa' 'South-East Asia' 'Africa'
#  'Africa' 'Western Pacific' 'Africa' 'Americas' 'Africa' 'Africa'
#  'Americas' 'Western Pacific' 'Americas' 'Africa' 'Africa' 'Africa'
#  'Americas' 'Africa' 'Europe' 'Americas' 'Europe' 'Europe' 'Europe'
#  'Eastern Mediterranean' 'Americas' 'Americas' 'Americas'
#  'Eastern Mediterranean' 'Americas' 'Africa' 'Africa' 'Europe' 'Africa'
#  'Africa' 'Western Pacific' 'Europe' 'Europe' 'Africa' 'Africa' 'Europe'
#  'Europe' 'Africa' 'Europe' 'Europe' 'Americas' 'Americas' 'Africa'
#  'Africa' 'Americas' 'Americas' 'Europe' 'Americas' 'Europe' 'Europe'
#  'South-East Asia' 'South-East Asia' 'Eastern Mediterranean'
# ...

# %% [markdown]
# ## Handling Missing Data

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer.fit(x_numerical)
x = np.nan_to_num(x, nan=np.nan, posinf=np.nan, neginf=np.nan)
x_numerical = x[:, 1:].astype(float)
x_numerical = np.clip(x_numerical, a_min=None, a_max=np.finfo(np.float64).max)

# %%
print(x)
# Out:
# [['Afghanistan' 36263.0 1269.0 ... 35526.0 737.0 2.07]
#  ['Albania' 4880.0 144.0 ... 4171.0 709.0 17.0]
#  ['Algeria' 27973.0 1163.0 ... 23691.0 4282.0 18.07]
#  ...
#  ['Yemen' 1691.0 483.0 ... 1619.0 72.0 4.45]
#  ['Zambia' 4552.0 140.0 ... 3326.0 1226.0 36.86]
#  ['Zimbabwe' 2704.0 36.0 ... 1713.0 991.0 57.85]]

# %%
imputer.fit(x[:, 1:4])
x[: , 1:4] = imputer.transform(x[:, 1:4])

# %%
print(x)
# Out:
# [['Afghanistan' 36263 1269 ... 35526 737 2.07]
#  ['Albania' 4880 144 ... 4171 709 17.0]
#  ['Algeria' 27973 1163 ... 23691 4282 18.07]
#  ...
#  ['Yemen' 1691 483 ... 1619 72 4.45]
#  ['Zambia' 4552 140 ... 3326 1226 36.86]
#  ['Zimbabwe' 2704 36 ... 1713 991 57.85]]

# %% [markdown]
# ## Encoding Categorical Data

# %% [markdown]
# ### Encoding independent variables

# %% [markdown]
# ### Encoding dependent variables

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Y=le.fit_transform(Y)

# %%
print(Y)
# Out:
# [2 3 0 3 0 1 1 3 5 3 3 1 2 4 1 3 3 1 0 4 1 3 0 1 5 3 0 4 0 0 5 0 1 0 0 1 5
#  1 0 0 0 1 0 3 1 3 3 3 2 1 1 1 2 1 0 0 3 0 0 5 3 3 0 0 3 3 0 3 3 1 1 0 0 1
#  1 3 1 3 3 4 4 2 2 3 3 3 1 5 2 3 0 3 2 3 5 3 2 0 0 2 3 3 3 0 0 5 4 0 3 0 0
#  1 3 3 5 3 2 0 0 4 3 5 1 0 0 3 3 2 2 1 5 1 1 5 3 3 2 3 3 0 1 1 1 3 0 2 0 3
#  0 0 5 3 3 2 0 5 0 3 4 2 1 3 3 2 5 3 0 4 4 0 1 2 3 1 0 3 2 3 1 3 1 5 2 0 2
#  0 0]

# %% [markdown]
# ## Splitting data into Test set & Training Set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,Y,test_size=0.2,random_state=42)

# %%
print(x_test)
# Out:
# [['Zambia' -0.19915579061478592 140.0 2815.0 1597 71 1 465 3.08 61.84
#   4.97 3326 1226 36.86]
#  ['Iceland' -0.20557565152536048 10.0 1823.0 21 7 0 0 0.54 98.33 0.55
#   1839 15 0.82]
#  ['Eritrea' -0.2093566593040495 0.0 191.0 74 2 0 2 0.0 72.08 0.0 251 14
#   5.58]
#  ['Romania' -0.10076392677036103 2206.0 25794.0 17902 1104 19 151 4.81
#   56.19 8.55 38139 7763 20.35]
#  ['Sweden' -0.02106770680080064 5700.0 0.0 73695 398 3 0 7.18 0.0 inf
#   78048 1347 1.73]
#  ['Belarus' -0.0499642193649287 538.0 60492.0 6221 119 4 67 0.8 89.95
#   0.89 66213 1038 1.57]
#  ['Holy See' -0.20995866998246884 0.0 12.0 0 0 0 0 0.0 100.0 0.0 12 0 0.0]
#  ['South Africa' 0.8668004848249702 7067.0 274925.0 170537 7096 298 9848
#   1.56 60.75 2.57 373628 78901 21.12]
#  ['Nicaragua' -0.20180416170206147 108.0 2492.0 839 0 0 0 3.14 72.46 4.33
#   3147 292 9.28]
#  ['Ukraine' -0.05033304013629233 1636.0 37202.0 28258 835 11 317 2.44
#   55.45 4.4 60767 6329 10.42]
# ...

# %%
print(y_test)
# Out:
# [0 3 0 3 3 3 3 0 1 3 4 0 3 5 1 3 0 3 3 4 0 0 1 0 5 3 3 3 3 3 0 3 1 0 3 1 0
#  2]

# %%
print(x_test)
# Out:
# [['Zambia' -0.19915579061478592 140.0 2815.0 1597 71 1 465 3.08 61.84
#   4.97 3326 1226 36.86]
#  ['Iceland' -0.20557565152536048 10.0 1823.0 21 7 0 0 0.54 98.33 0.55
#   1839 15 0.82]
#  ['Eritrea' -0.2093566593040495 0.0 191.0 74 2 0 2 0.0 72.08 0.0 251 14
#   5.58]
#  ['Romania' -0.10076392677036103 2206.0 25794.0 17902 1104 19 151 4.81
#   56.19 8.55 38139 7763 20.35]
#  ['Sweden' -0.02106770680080064 5700.0 0.0 73695 398 3 0 7.18 0.0 inf
#   78048 1347 1.73]
#  ['Belarus' -0.0499642193649287 538.0 60492.0 6221 119 4 67 0.8 89.95
#   0.89 66213 1038 1.57]
#  ['Holy See' -0.20995866998246884 0.0 12.0 0 0 0 0 0.0 100.0 0.0 12 0 0.0]
#  ['South Africa' 0.8668004848249702 7067.0 274925.0 170537 7096 298 9848
#   1.56 60.75 2.57 373628 78901 21.12]
#  ['Nicaragua' -0.20180416170206147 108.0 2492.0 839 0 0 0 3.14 72.46 4.33
#   3147 292 9.28]
#  ['Ukraine' -0.05033304013629233 1636.0 37202.0 28258 835 11 317 2.44
#   55.45 4.4 60767 6329 10.42]
# ...

# %%
print(y_train)
# Out:
# [3 1 0 0 3 3 3 0 2 1 3 5 2 2 0 0 3 2 3 2 1 0 3 3 3 3 5 0 3 5 3 0 3 2 4 1 1
#  3 1 4 0 0 1 2 5 3 1 3 0 0 1 2 4 1 1 3 3 1 3 0 0 3 0 3 1 0 2 4 3 0 0 1 3 5
#  0 3 5 1 0 3 1 0 3 1 0 0 2 2 3 5 1 4 1 1 4 0 3 0 3 3 5 0 3 5 4 5 2 1 1 0 2
#  3 5 2 0 0 0 1 0 0 2 2 3 0 1 1 1 1 3 2 3 2 0 5 3 0 2 2 5 1 5 0 1 0 4 1 2 3
#  3]

# %% [markdown]
# ## Feature Scaling

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

x_train = np.nan_to_num(x_train, nan=np.nan, posinf=np.nan, neginf=np.nan)
x_test = np.nan_to_num(x_test, nan=np.nan, posinf=np.nan, neginf=np.nan)

sc = StandardScaler()

x_train[:, 1:2] = sc.fit_transform(x_train[:, 1:2])
x_test[:, 1:2] = sc.transform(x_test[:, 1:2])

# %%
print(y_train)
# Out:
# [3 1 0 0 3 3 3 0 2 1 3 5 2 2 0 0 3 2 3 2 1 0 3 3 3 3 5 0 3 5 3 0 3 2 4 1 1
#  3 1 4 0 0 1 2 5 3 1 3 0 0 1 2 4 1 1 3 3 1 3 0 0 3 0 3 1 0 2 4 3 0 0 1 3 5
#  0 3 5 1 0 3 1 0 3 1 0 0 2 2 3 5 1 4 1 1 4 0 3 0 3 3 5 0 3 5 4 5 2 1 1 0 2
#  3 5 2 0 0 0 1 0 0 2 2 3 0 1 1 1 1 3 2 3 2 0 5 3 0 2 2 5 1 5 0 1 0 4 1 2 3
#  3]
